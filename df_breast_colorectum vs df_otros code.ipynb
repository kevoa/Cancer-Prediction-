# %%
# Cargar librerías
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split, cross_val_score, RepeatedStratifiedKFold
from sklearn.preprocessing import OrdinalEncoder, StandardScaler, OneHotEncoder
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, GradientBoostingClassifier
from sklearn.neighbors import KNeighborsClassifier
from imblearn.under_sampling import RandomUnderSampler, NearMiss
from imblearn.pipeline import Pipeline
from imblearn.under_sampling import CondensedNearestNeighbour
from sklearn.compose import ColumnTransformer
from sklearn.pipeline import Pipeline
from sklearn.impute import SimpleImputer
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, confusion_matrix
from ctgan import CTGAN
import warnings
warnings.filterwarnings("ignore", category=FutureWarning)

# Cargamos los datos de un fichero excel
file_path = 'D:/MÁSTER DATA SCIENCE/KSCHOOL/1.TFM/PARTTE 2 TFM/df_final.xlsx'
df = pd.read_excel(file_path)

# %% [markdown]
# # DEFINIR FUNCIONES

# %%
# Identificar características numéricas y categóricas
numeric_features = df.select_dtypes(include=[float, int]).columns.tolist()
categorical_features = df.select_dtypes(include=['object', 'category']).columns.tolist()

df[numeric_features]= df[numeric_features].fillna(df[numeric_features].mean().round(1), inplace=False)
# Preprocesamiento para las características numéricas
numeric_transformer = Pipeline(steps=[
    ('imputer', SimpleImputer(strategy='median')),  # Imputación con la mediana
    ('scaler', StandardScaler())  # Estandarización
])

# Preprocesamiento para las características categóricas ordinales
ordinal_features = ['AJCC Stage']
ordinal_transformer = Pipeline(steps=[
    ('label', OrdinalEncoder(dtype=int))  # Codificación Ordinal
])

# Preprocesamiento para las características categóricas nominales (binarias)
nominal_features = ['Sex']
nominal_transformer = Pipeline(steps=[
    ('onehot', OneHotEncoder(drop='if_binary', dtype=int))  # Codificación binaria
])

# Combinación de los transformadores en un preprocesador
preprocessor = ColumnTransformer(
    transformers=[
        ('num', numeric_transformer, numeric_features),
        ('ord', ordinal_transformer, ordinal_features),
        ('nom', nominal_transformer, nominal_features)
    ])

# Función para entrenar y evaluar modelos
def entrenar_y_evaluar_modelo(X_train, y_train, X_test, y_test, model, model_name):
    try:
        # Cross validation
        cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3, random_state=1)
        scores = cross_val_score(model, X_train, y_train, scoring='accuracy', cv=cv, n_jobs=1)
        print(f"Cross-validated accuracy: {scores.mean():.4f}")

        # Entrenar el modelo
        model.fit(X_train, y_train)

        # Evaluar en el conjunto de entrenamiento
        y_train_pred = model.predict(X_train)
        mostrar_estadisticas_guardar_tabla(y_train, y_train_pred, "Training", model_name)

        # Evaluar en el conjunto de prueba
        y_test_pred = model.predict(X_test)
        mostrar_estadisticas_guardar_tabla(y_test, y_test_pred, "Test", model_name)

    except Exception as e:
        print(f"Error al entrenar o evaluar el modelo {model_name}: {e}")
        
# Definir funciones para evaluación y resultados
def mostrar_estadisticas_guardar_tabla(y_val, y_pred, set_name, model_name):
    global tabla_results_df
    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred, average='weighted')
    recall = recall_score(y_val, y_pred, average='weighted')
    f1 = f1_score(y_val, y_pred, average='weighted')

    print(f'Model performance for {set_name} - {model_name}')
    print("- Accuracy: {:.4f}".format(accuracy))
    print('- F1 score: {:.4f}'.format(f1))
    print('- Precision: {:.4f}'.format(precision))
    print('- Recall: {:.4f}'.format(recall))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))

    global_score = calcular_puntuacion_global(accuracy, precision, recall, f1)

    new_row = pd.DataFrame({
        'Model': [model_name],
        'Set': [set_name],
        'Accuracy': [accuracy],
        'Precision': [precision],
        'Recall': [recall],
        'F1-Score': [f1],
        'Global Score' : [global_score]
    })

    tabla_results_df = pd.concat([tabla_results_df, new_row], ignore_index=True)

    return tabla_results_df


def calcular_puntuacion_global(accuracy, precision, recall, f1):
    # Definir ponderaciones para cada métrica
    weights = {
        'accuracy': 0.25,
        'precision': 0.25,
        'recall': 0.25,
        'f1': 0.25,
    }

    # Calcular la puntuación global
    global_score = (accuracy * weights['accuracy'] +
                    precision * weights['precision'] +
                    recall * weights['recall'] +
                    f1 * weights['f1'])

    return round(global_score * 100, 2)

# %%
# Filtrar el DataFrame
df_breast_colorectum = df[df['Tumor type'].isin(['Breast', 'Colorectum'])]
df_otros = df[df['Tumor type'].isin(['Esophagus', 'Liver', 'Lung', 'Ovary', 'Pancreas', 'Stomach'])]

# Imprimir resultados
print("Parte 1:")
print(df_breast_colorectum)
print("\nParte 2:")
print(df_otros)
# Out:
# Parte 1:
#      Unnamed: 0  Tumor type AJCC Stage  AFP (pg/ml)  Angiopoietin-2 (pg/ml)  \
# 0             0  Colorectum          I     1583.450                 5598.50
# 1             1  Colorectum          I      715.308                20936.35
# 2             2  Colorectum         II     4365.530                 2350.93
# 3             3  Colorectum         II      715.308                 1604.34
# 4             4  Colorectum         II      801.300                 2087.57
# ..          ...         ...        ...          ...                     ...
# 874         874      Breast         II     1200.090                 2997.73
# 876         876      Breast        III      792.540                 1727.85
# 877         877      Breast         II      792.540                  988.43
# 878         878      Breast         II     3311.130                 6524.83
# 888         896  Colorectum          I      913.980                  159.97
#
#      AXL (pg/ml)  CA-125 (U/ml)  CA 15-3 (U/ml)  CA19-9 (U/ml)  CD44 (ng/ml)  \
# 0        3621.04          5.090           19.08         16.452          9.81
# 1        2772.96          7.270           10.04         40.910         27.57
# 2        4120.77          4.854           16.96         16.452         14.59
# 3        2029.96          5.390            8.31         16.452          7.78
# 4        2069.17          4.854           11.73         16.452         12.21
# ..           ...            ...             ...            ...           ...
# 874      1994.41          4.920           15.12         16.440          9.79
# 876      2628.76          4.920           12.76         16.440         12.74
# 877      2416.20          4.920            3.79         16.440         16.24
# 878      2183.11          4.920           16.92         16.440          9.65
# 888      4318.06          6.120            4.59         33.230         21.45
#
#      ...  sFas (pg/ml)  SHBG (nM)  sHER2/sEGFR2/sErbB2 (pg/ml)  \
# 0    ...       204.792      55.06                      6832.07
# 1    ...       204.792      72.92                      5549.47
# 2    ...       204.792     173.78                      3698.16
# 3    ...       204.792      29.47                      5856.00
# 4    ...       204.792      78.07                      5447.93
# ..   ...           ...        ...                          ...
# 874  ...       952.790     116.82                      6105.04
# 876  ...       930.950      72.13                      5091.33
# 877  ...       352.960      88.08                      4169.86
# 878  ...      1018.110     212.33                      6326.91
# 888  ...       200.436      84.89                      7703.82
#
#      sPECAM-1 (pg/ml)  TGFa (pg/ml)  Thrombospondin-2 (pg/ml)  TIMP-1 (pg/ml)  \
# 0             9368.53        16.086                  21863.74        56428.71
# 1             6224.55        16.086                  29669.66        73940.49
# 2             4046.48       179.030                   6020.47        22797.28
# 3             6121.93        16.086                   4331.02        20441.19
# 4             6982.32        16.086                   2311.91        56288.51
# ..                ...           ...                       ...             ...
# 874           6564.52        16.488                   8958.15        56277.55
# 876           4658.47        16.488                   4670.50        74353.54
# 877           5252.83        16.488                   2225.75        48126.04
# 878           5055.07        16.488                   4263.34        62117.26
# 888          12037.97        16.692                  17623.48        60285.86
#
#      TIMP-2 (pg/ml)  Omega score     Sex
# 0          39498.82     2.962820    Male
# 1          41277.09     2.445405  Female
# 2          28440.60     1.215758  Female
# 3          25896.73     1.640793  Female
# 4          49425.20     1.325771  Female
# ..              ...          ...     ...
# 874        45132.24     0.955718  Female
# 876        55619.85     1.684380  Female
# 877        47208.97     1.371042  Female
# 878        47778.33     1.162175  Female
# 888        46525.99     0.409046    Male
#
# [597 rows x 44 columns]
#
# Parte 2:
#       Unnamed: 0 Tumor type AJCC Stage  AFP (pg/ml)  Angiopoietin-2 (pg/ml)  \
# 76            76       Lung         II      781.392                 4050.94
# 77            77       Lung         II      781.392                 1204.80
# 78            78       Lung        III     5337.000                 1034.19
# 79            79       Lung          I      781.392                 2203.07
# 80            80       Lung          I      781.392                 1860.67
# ...          ...        ...        ...          ...                     ...
# 1000        1812      Ovary          I      879.498                 1484.70
# 1001        1813      Ovary          I     1337.330                 1607.90
# 1002        1814      Ovary        III      879.498                 1592.84
# 1003        1815      Ovary         II      879.498                 5267.95
# 1004        1816      Ovary        III      879.498                 3546.43
#
#       AXL (pg/ml)  CA-125 (U/ml)  CA 15-3 (U/ml)  CA19-9 (U/ml)  CD44 (ng/ml)  \
# 76        2561.78           4.77            5.27         15.798         25.95
# 77         918.55           5.49           19.86         22.760         11.51
# 78        2507.12         169.14           36.28        476.960         18.42
# 79        2782.18           4.77           11.09        149.330         17.29
# 80        4122.82           4.77            5.36         15.798          9.71
# ...           ...            ...             ...            ...           ...
# 1000      2096.76          24.82           10.30         42.390         14.92
# 1001       852.37           5.58            9.80         16.440         12.32
# 1002      1044.45          30.48            8.48         16.440          8.26
# 1003      1445.69        1469.45           23.74         62.260         16.53
# 1004      1493.32        1428.31          836.85         37.900         13.78
#
#       ...  sFas (pg/ml)  SHBG (nM)  sHER2/sEGFR2/sErbB2 (pg/ml)  \
# 76    ...       202.158      57.45                      5084.34
# 77    ...       202.158     172.90                      5778.95
# 78    ...       202.158      78.68                      4853.14
# 79    ...       202.158      77.90                      6935.33
# 80    ...       202.158     160.47                      2106.35
# ...   ...           ...        ...                          ...
# 1000  ...       207.240     115.24                      5390.31
# 1001  ...       207.240     147.17                      7951.03
# 1002  ...       207.240     104.63                      2396.36
# 1003  ...       207.240      73.55                      3079.81
# 1004  ...       207.240      72.22                      3967.55
#
#       sPECAM-1 (pg/ml)  TGFa (pg/ml)  Thrombospondin-2 (pg/ml)  \
# 76             6154.94        16.104                  6264.920
# 77             5027.85        16.104                  5095.230
# 78             5082.54        16.104                  2229.275
# 79             5545.11        16.104                  2229.275
# 80             4710.58        16.104                  2229.275
# ...                ...           ...                       ...
# 1000           8538.58        16.890                   599.400
# 1001          12966.19        16.890                   599.400
# 1002           1901.41        16.890                   599.400
# 1003           5312.90        16.890                  6864.330
# 1004           4045.18        16.890                 12877.100
#
#       TIMP-1 (pg/ml)  TIMP-2 (pg/ml)  Omega score     Sex
# 76         136363.01        57377.78     0.837332  Female
# 77          72112.49        59669.66     0.571841  Female
# 78          73931.88        59388.49     1.701628    Male
# 79          86067.68        57704.59     0.667789    Male
# 80          81139.74        66179.40     0.766007    Male
# ...              ...             ...          ...     ...
# 1000       167799.61        50128.60     0.983813  Female
# 1001       123443.76        54066.98     3.915387  Female
# 1002       104070.89        39844.02     7.962561  Female
# 1003       110579.24        42921.13     0.807685  Female
# 1004        88464.04        47219.24     1.425203  Female
#
# [408 rows x 44 columns]

# %%
#Crear los 2 dataframes

df_breast_colorectum.to_excel('df_breast_colorectum.xlsx', index=False) 
df_otros.to_excel('df_otros.xlsx', index=False)

# %%
df_breast_colorectum.isnull().sum()
# Out:
# Unnamed: 0                     0
# Tumor type                     0
# AJCC Stage                     0
# AFP (pg/ml)                    0
# Angiopoietin-2 (pg/ml)         0
# AXL (pg/ml)                    0
# CA-125 (U/ml)                  0
# CA 15-3 (U/ml)                 0
# CA19-9 (U/ml)                  0
# CD44 (ng/ml)                   0
# CEA (pg/ml)                    0
# CYFRA 21-1 (pg/ml)             0
# DKK1 (ng/ml)                   0
# Endoglin (pg/ml)               0
# FGF2 (pg/ml)                   0
# Follistatin (pg/ml)            0
# Galectin-3 (ng/ml)             0
# G-CSF (pg/ml)                  0
# GDF15 (ng/ml)                  0
# HE4 (pg/ml)                    0
# HGF (pg/ml)                    0
# IL-6 (pg/ml)                   0
# IL-8 (pg/ml)                   0
# Kallikrein-6 (pg/ml)           0
# Leptin (pg/ml)                 0
# Mesothelin (ng/ml)             0
# Midkine (pg/ml)                0
# Myeloperoxidase (ng/ml)        0
# NSE (ng/ml)                    0
# OPG (ng/ml)                    0
# OPN (pg/ml)                    0
# PAR (pg/ml)                    0
# Prolactin (pg/ml)              0
# sEGFR (pg/ml)                  0
# sFas (pg/ml)                   0
# SHBG (nM)                      0
# sHER2/sEGFR2/sErbB2 (pg/ml)    0
# sPECAM-1 (pg/ml)               0
# TGFa (pg/ml)                   0
# Thrombospondin-2 (pg/ml)       0
# TIMP-1 (pg/ml)                 0
# TIMP-2 (pg/ml)                 0
# Omega score                    0
# Sex                            0
# dtype: int64

# %%
# Separar las características (X) y la variable objetivo (y)
X = df_breast_colorectum.drop(columns=['Tumor type'])
y = df_breast_colorectum['Tumor type']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Procesar características categóricas
ordinal_encoder = OrdinalEncoder()
categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()
X_train[categorical_features] = ordinal_encoder.fit_transform(X_train[categorical_features])
X_test[categorical_features] = ordinal_encoder.transform(X_test[categorical_features])

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir X_train y y_train en un DataFrame para CTGAN
X_train_df = pd.DataFrame(X_train, columns=[f"feature_{i}" for i in range(X_train.shape[1])])
X_train_df['Tumor type'] = y_train.values

# Definir los modelos y estrategias de balanceo
modelos = {
    'Logistic Regression': LogisticRegression(max_iter=5000),  # Aumentar max_iter
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'AdaBoost': AdaBoostClassifier(algorithm='SAMME'),  # Usar algoritmo SAMME
    'Gradient Boosting': GradientBoostingClassifier()
}

estrategias_balanceo = {
    'RandomUnderSampler': RandomUnderSampler(random_state=42),
    'NearMiss': NearMiss(),
    'CondensedNearestNeighbour': CondensedNearestNeighbour(random_state=42),
    'CTGAN': CTGAN(),
    'CTGAN + RandomUnderSampler': Pipeline([
        ('ctgan', CTGAN()),
        ('under', RandomUnderSampler(random_state=42))
    ])
}

# Inicializar el DataFrame de resultados
tabla_results_df = pd.DataFrame(columns=['Model', 'Set', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'Global Score'])

def entrenar_y_evaluar_modelo(X_train_balanced, y_train_balanced, X_test, y_test, modelo, model_name):
    try:
        # Entrenar el modelo
        modelo.fit(X_train_balanced, y_train_balanced)

        # Evaluar en el conjunto de prueba
        y_test_pred = modelo.predict(X_test)
        mostrar_estadisticas_guardar_tabla(y_test, y_test_pred, "Test", model_name)

    except Exception as e:
        print(f"Error al entrenar o evaluar el modelo {model_name}: {e}")

def mostrar_estadisticas_guardar_tabla(y_val, y_pred, set_name, model_name):
    global tabla_results_df
    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred, average='weighted')
    recall = recall_score(y_val, y_pred, average='weighted')
    f1 = f1_score(y_val, y_pred, average='weighted')

    print(f'Model performance for {set_name} - {model_name}')
    print("- Accuracy: {:.4f}".format(accuracy))
    print('- F1 score: {:.4f}'.format(f1))
    print('- Precision: {:.4f}'.format(precision))
    print('- Recall: {:.4f}'.format(recall))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))

    global_score = calcular_puntuacion_global(accuracy, precision, recall, f1)

    new_row = pd.DataFrame({
        'Model df_breast_colorectum': [model_name],
        'Set df_breast_colorectum': [set_name],
        'Accuracy df_breast_colorectum': [accuracy],
        'Precision df_breast_colorectum': [precision],
        'Recall df_breast_colorectum': [recall],
        'F1-Score df_breast_colorectum': [f1],
        'Global Score df_breast_colorectum': [global_score]
    })

    tabla_results_df = pd.concat([tabla_results_df, new_row], ignore_index=True)

def calcular_puntuacion_global(accuracy, precision, recall, f1):
    # Definir ponderaciones para cada métrica
    weights = {
        'accuracy': 0.25,
        'precision': 0.25,
        'recall': 0.25,
        'f1': 0.25,
    }

    # Calcular la puntuación global
    global_score = (accuracy * weights['accuracy'] +
                    precision * weights['precision'] +
                    recall * weights['recall'] +
                    f1 * weights['f1'])

    return round(global_score * 100, 2)

# Entrenar y evaluar modelos para cada estrategia de balanceo
for estrategia_nombre, estrategia in estrategias_balanceo.items():
    print(f"\nEstrategia de balanceo: {estrategia_nombre}")

    if estrategia_nombre == 'CTGAN':
        # Entrenar CTGAN y generar datos sintéticos
        ctgan = CTGAN()
        ctgan.fit(X_train_df, discrete_columns=['Tumor type'])
        samples = ctgan.sample(len(X_train_df))
        X_train_balanced = samples.drop(columns=['Tumor type']).values
        y_train_balanced = samples['Tumor type'].values
    elif estrategia_nombre == 'CTGAN + RandomUnderSampler':
        # Entrenar CTGAN y generar datos sintéticos
        ctgan = CTGAN()
        ctgan.fit(X_train_df, discrete_columns=['Tumor type'])
        samples = ctgan.sample(len(X_train_df))
        X_synthetic = samples.drop(columns=['Tumor type']).values
        y_synthetic = samples['Tumor type'].values
        # Combinar datos sintéticos con datos reales
        X_combined = np.vstack([X_train, X_synthetic])
        y_combined = np.hstack([y_train, y_synthetic])
        X_train_balanced, y_train_balanced = RandomUnderSampler(random_state=42).fit_resample(X_combined, y_combined)
    else:
        X_train_balanced, y_train_balanced = estrategia.fit_resample(X_train, y_train)

    for modelo_nombre, modelo in modelos.items():
        print(f"\nModelo: {modelo_nombre}")
        model_name = f"{modelo_nombre} ({estrategia_nombre})"
        entrenar_y_evaluar_modelo(X_train_balanced, y_train_balanced, X_test, y_test, modelo, model_name)

# Guardar los resultados en un archivo Excel
tabla_results_df.to_excel('tabla_results_df_breast_colorectum.xlsx', index=False)
# Out:
# Estrategia de balanceo: RandomUnderSampler
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (RandomUnderSampler)
# - Accuracy: 0.8667
# - F1 score: 0.8679
# - Precision: 0.8701
# - Recall: 0.8667
# Confusion Matrix:
#  [[ 45  10]
#  [ 14 111]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (RandomUnderSampler)
# - Accuracy: 0.8556
# - F1 score: 0.8586
# - Precision: 0.8671
# - Recall: 0.8556
# Confusion Matrix:
#  [[ 47   8]
#  [ 18 107]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (RandomUnderSampler)
# - Accuracy: 0.9000
# - F1 score: 0.9021
# - Precision: 0.9100
# - Recall: 0.9000
# Confusion Matrix:
#  [[ 51   4]
#  [ 14 111]]
#
# Modelo: KNN
# Model performance for Test - KNN (RandomUnderSampler)
# - Accuracy: 0.8056
# - F1 score: 0.8119
# - Precision: 0.8361
# - Recall: 0.8056
# Confusion Matrix:
#  [[47  8]
#  [27 98]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (RandomUnderSampler)
# - Accuracy: 0.8944
# - F1 score: 0.8961
# - Precision: 0.9006
# - Recall: 0.8944
# Confusion Matrix:
#  [[ 49   6]
#  [ 13 112]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (RandomUnderSampler)
# - Accuracy: 0.9167
# - F1 score: 0.9176
# - Precision: 0.9201
# - Recall: 0.9167
# Confusion Matrix:
#  [[ 50   5]
#  [ 10 115]]
#
# Estrategia de balanceo: NearMiss
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (NearMiss)
# - Accuracy: 0.8778
# - F1 score: 0.8778
# - Precision: 0.8778
# - Recall: 0.8778
# Confusion Matrix:
#  [[ 44  11]
#  [ 11 114]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (NearMiss)
# - Accuracy: 0.8389
# - F1 score: 0.8393
# - Precision: 0.8397
# - Recall: 0.8389
# Confusion Matrix:
#  [[ 41  14]
#  [ 15 110]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (NearMiss)
# - Accuracy: 0.9333
# - F1 score: 0.9333
# - Precision: 0.9333
# - Recall: 0.9333
# Confusion Matrix:
#  [[ 49   6]
#  [  6 119]]
#
# Modelo: KNN
# Model performance for Test - KNN (NearMiss)
# - Accuracy: 0.8278
# - F1 score: 0.8290
# - Precision: 0.8308
# - Recall: 0.8278
# Confusion Matrix:
#  [[ 41  14]
#  [ 17 108]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (NearMiss)
# - Accuracy: 0.9167
# - F1 score: 0.9169
# - Precision: 0.9171
# - Recall: 0.9167
# Confusion Matrix:
#  [[ 48   7]
#  [  8 117]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (NearMiss)
# - Accuracy: 0.9611
# - F1 score: 0.9612
# - Precision: 0.9614
# - Recall: 0.9611
# Confusion Matrix:
#  [[ 52   3]
#  [  4 121]]
#
# Estrategia de balanceo: CondensedNearestNeighbour
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CondensedNearestNeighbour)
# - Accuracy: 0.8833
# - F1 score: 0.8842
# - Precision: 0.8856
# - Recall: 0.8833
# Confusion Matrix:
#  [[ 46   9]
#  [ 12 113]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CondensedNearestNeighbour)
# - Accuracy: 0.8556
# - F1 score: 0.8590
# - Precision: 0.8703
# - Recall: 0.8556
# Confusion Matrix:
#  [[ 48   7]
#  [ 19 106]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (CondensedNearestNeighbour)
# - Accuracy: 0.9056
# - F1 score: 0.9082
# - Precision: 0.9238
# - Recall: 0.9056
# Confusion Matrix:
#  [[ 54   1]
#  [ 16 109]]
#
# Modelo: KNN
# Model performance for Test - KNN (CondensedNearestNeighbour)
# - Accuracy: 0.7500
# - F1 score: 0.7597
# - Precision: 0.8075
# - Recall: 0.7500
# Confusion Matrix:
#  [[47  8]
#  [37 88]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CondensedNearestNeighbour)
# - Accuracy: 0.9000
# - F1 score: 0.9017
# - Precision: 0.9073
# - Recall: 0.9000
# Confusion Matrix:
#  [[ 50   5]
#  [ 13 112]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CondensedNearestNeighbour)
# - Accuracy: 0.9167
# - F1 score: 0.9188
# - Precision: 0.9309
# - Recall: 0.9167
# Confusion Matrix:
#  [[ 54   1]
#  [ 14 111]]
#
# Estrategia de balanceo: CTGAN
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CTGAN)
# - Accuracy: 0.5778
# - F1 score: 0.5323
# - Precision: 0.5020
# - Recall: 0.5778
# Confusion Matrix:
#  [[  4  51]
#  [ 25 100]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CTGAN)
# - Accuracy: 0.5944
# - F1 score: 0.5739
# - Precision: 0.5602
# - Recall: 0.5944
# Confusion Matrix:
#  [[11 44]
#  [29 96]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (CTGAN)
# - Accuracy: 0.6278
# - F1 score: 0.5507
# - Precision: 0.5082
# - Recall: 0.6278
# Confusion Matrix:
#  [[  2  53]
#  [ 14 111]]
#
# Modelo: KNN
# Model performance for Test - KNN (CTGAN)
# - Accuracy: 0.5500
# - F1 score: 0.5232
# - Precision: 0.5031
# - Recall: 0.5500
# Confusion Matrix:
#  [[ 6 49]
#  [32 93]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CTGAN)
# - Accuracy: 0.6667
# - F1 score: 0.5877
# - Precision: 0.5764
# - Recall: 0.6667
# Confusion Matrix:
#  [[  4  51]
#  [  9 116]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CTGAN)
# - Accuracy: 0.6389
# - F1 score: 0.5495
# - Precision: 0.4967
# - Recall: 0.6389
# Confusion Matrix:
#  [[  1  54]
#  [ 11 114]]
#
# Estrategia de balanceo: CTGAN + RandomUnderSampler
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CTGAN + RandomUnderSampler)
# - Accuracy: 0.8444
# - F1 score: 0.8459
# - Precision: 0.8483
# - Recall: 0.8444
# Confusion Matrix:
#  [[ 43  12]
#  [ 16 109]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CTGAN + RandomUnderSampler)
# - Accuracy: 0.7833
# - F1 score: 0.7888
# - Precision: 0.8026
# - Recall: 0.7833
# Confusion Matrix:
#  [[42 13]
#  [26 99]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (CTGAN + RandomUnderSampler)
# - Accuracy: 0.9222
# - F1 score: 0.9233
# - Precision: 0.9266
# - Recall: 0.9222
# Confusion Matrix:
#  [[ 51   4]
#  [ 10 115]]
#
# Modelo: KNN
# Model performance for Test - KNN (CTGAN + RandomUnderSampler)
# - Accuracy: 0.8111
# - F1 score: 0.8150
# - Precision: 0.8241
# - Recall: 0.8111
# Confusion Matrix:
#  [[ 43  12]
#  [ 22 103]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CTGAN + RandomUnderSampler)
# - Accuracy: 0.8167
# - F1 score: 0.8195
# - Precision: 0.8249
# - Recall: 0.8167
# Confusion Matrix:
#  [[ 42  13]
#  [ 20 105]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CTGAN + RandomUnderSampler)
# - Accuracy: 0.9056
# - F1 score: 0.9074
# - Precision: 0.9140
# - Recall: 0.9056
# Confusion Matrix:
#  [[ 51   4]
#  [ 13 112]]

# %%
df_otros.isnull().sum()
# Out:
# Unnamed: 0                     0
# Tumor type                     0
# AJCC Stage                     0
# AFP (pg/ml)                    0
# Angiopoietin-2 (pg/ml)         0
# AXL (pg/ml)                    0
# CA-125 (U/ml)                  0
# CA 15-3 (U/ml)                 0
# CA19-9 (U/ml)                  0
# CD44 (ng/ml)                   0
# CEA (pg/ml)                    0
# CYFRA 21-1 (pg/ml)             0
# DKK1 (ng/ml)                   0
# Endoglin (pg/ml)               0
# FGF2 (pg/ml)                   0
# Follistatin (pg/ml)            0
# Galectin-3 (ng/ml)             0
# G-CSF (pg/ml)                  0
# GDF15 (ng/ml)                  0
# HE4 (pg/ml)                    0
# HGF (pg/ml)                    0
# IL-6 (pg/ml)                   0
# IL-8 (pg/ml)                   0
# Kallikrein-6 (pg/ml)           0
# Leptin (pg/ml)                 0
# Mesothelin (ng/ml)             0
# Midkine (pg/ml)                0
# Myeloperoxidase (ng/ml)        0
# NSE (ng/ml)                    0
# OPG (ng/ml)                    0
# OPN (pg/ml)                    0
# PAR (pg/ml)                    0
# Prolactin (pg/ml)              0
# sEGFR (pg/ml)                  0
# sFas (pg/ml)                   0
# SHBG (nM)                      0
# sHER2/sEGFR2/sErbB2 (pg/ml)    0
# sPECAM-1 (pg/ml)               0
# TGFa (pg/ml)                   0
# Thrombospondin-2 (pg/ml)       0
# TIMP-1 (pg/ml)                 0
# TIMP-2 (pg/ml)                 0
# Omega score                    0
# Sex                            0
# dtype: int64

# %%
# Separar las características (X) y la variable objetivo (y)
X = df_otros.drop(columns=['Tumor type'])
y = df_otros['Tumor type']

# Dividir los datos en conjuntos de entrenamiento y prueba
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=42)

# Procesar características categóricas
ordinal_encoder = OrdinalEncoder()
categorical_features = X.select_dtypes(include=['object', 'category']).columns.tolist()
X_train[categorical_features] = ordinal_encoder.fit_transform(X_train[categorical_features])
X_test[categorical_features] = ordinal_encoder.transform(X_test[categorical_features])

# Escalar los datos
scaler = StandardScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# Convertir X_train y y_train en un DataFrame para CTGAN
X_train_df = pd.DataFrame(X_train, columns=[f"feature_{i}" for i in range(X_train.shape[1])])
X_train_df['Tumor type'] = y_train.values

# Definir los modelos y estrategias de balanceo
modelos = {
    'Logistic Regression': LogisticRegression(max_iter=5000),  # Aumentar max_iter
    'Decision Tree': DecisionTreeClassifier(),
    'Random Forest': RandomForestClassifier(),
    'KNN': KNeighborsClassifier(),
    'AdaBoost': AdaBoostClassifier(algorithm='SAMME'),  # Usar algoritmo SAMME
    'Gradient Boosting': GradientBoostingClassifier()
}

estrategias_balanceo = {
    'RandomUnderSampler': RandomUnderSampler(random_state=42),
    'NearMiss': NearMiss(),
    'CondensedNearestNeighbour': CondensedNearestNeighbour(random_state=42),
    'CTGAN': CTGAN(),
    'CTGAN + RandomUnderSampler': Pipeline([
        ('ctgan', CTGAN()),
        ('under', RandomUnderSampler(random_state=42))
    ])
}

# Inicializar el DataFrame de resultados
tabla_results_df = pd.DataFrame(columns=['Model', 'Set', 'Accuracy', 'Precision', 'Recall', 'F1-Score', 'Global Score'])

def entrenar_y_evaluar_modelo(X_train_balanced, y_train_balanced, X_test, y_test, modelo, model_name):
    try:
        # Entrenar el modelo
        modelo.fit(X_train_balanced, y_train_balanced)

        # Evaluar en el conjunto de prueba
        y_test_pred = modelo.predict(X_test)
        mostrar_estadisticas_guardar_tabla(y_test, y_test_pred, "Test", model_name)

    except Exception as e:
        print(f"Error al entrenar o evaluar el modelo {model_name}: {e}")

def mostrar_estadisticas_guardar_tabla(y_val, y_pred, set_name, model_name):
    global tabla_results_df
    accuracy = accuracy_score(y_val, y_pred)
    precision = precision_score(y_val, y_pred, average='weighted')
    recall = recall_score(y_val, y_pred, average='weighted')
    f1 = f1_score(y_val, y_pred, average='weighted')

    print(f'Model performance for {set_name} - {model_name}')
    print("- Accuracy: {:.4f}".format(accuracy))
    print('- F1 score: {:.4f}'.format(f1))
    print('- Precision: {:.4f}'.format(precision))
    print('- Recall: {:.4f}'.format(recall))
    print("Confusion Matrix:\n", confusion_matrix(y_val, y_pred))

    global_score = calcular_puntuacion_global(accuracy, precision, recall, f1)

    new_row = pd.DataFrame({
        'Model df_otros ': [model_name],
        'Set df_otros ': [set_name],
        'Accuracy df_otros ': [accuracy],
        'Precision df_otros ': [precision],
        'Recall df_otros ': [recall],
        'F1-Score df_otros ': [f1],
        'Global Score df_otros ': [global_score]
    })

    tabla_results_df = pd.concat([tabla_results_df, new_row], ignore_index=True)

def calcular_puntuacion_global(accuracy, precision, recall, f1):
    # Definir ponderaciones para cada métrica
    weights = {
        'accuracy': 0.25,
        'precision': 0.25,
        'recall': 0.25,
        'f1': 0.25,
    }

    # Calcular la puntuación global
    global_score = (accuracy * weights['accuracy'] +
                    precision * weights['precision'] +
                    recall * weights['recall'] +
                    f1 * weights['f1'])

    return round(global_score * 100, 2)

# Entrenar y evaluar modelos para cada estrategia de balanceo
for estrategia_nombre, estrategia in estrategias_balanceo.items():
    print(f"\nEstrategia de balanceo: {estrategia_nombre}")

    if estrategia_nombre == 'CTGAN':
        # Entrenar CTGAN y generar datos sintéticos
        ctgan = CTGAN()
        ctgan.fit(X_train_df, discrete_columns=['Tumor type'])
        samples = ctgan.sample(len(X_train_df))
        X_train_balanced = samples.drop(columns=['Tumor type']).values
        y_train_balanced = samples['Tumor type'].values
    elif estrategia_nombre == 'CTGAN + RandomUnderSampler':
        # Entrenar CTGAN y generar datos sintéticos
        ctgan = CTGAN()
        ctgan.fit(X_train_df, discrete_columns=['Tumor type'])
        samples = ctgan.sample(len(X_train_df))
        X_synthetic = samples.drop(columns=['Tumor type']).values
        y_synthetic = samples['Tumor type'].values
        # Combinar datos sintéticos con datos reales
        X_combined = np.vstack([X_train, X_synthetic])
        y_combined = np.hstack([y_train, y_synthetic])
        X_train_balanced, y_train_balanced = RandomUnderSampler(random_state=42).fit_resample(X_combined, y_combined)
    else:
        X_train_balanced, y_train_balanced = estrategia.fit_resample(X_train, y_train)

    for modelo_nombre, modelo in modelos.items():
        print(f"\nModelo: {modelo_nombre}")
        model_name = f"{modelo_nombre} ({estrategia_nombre})"
        entrenar_y_evaluar_modelo(X_train_balanced, y_train_balanced, X_test, y_test, modelo, model_name)

# Guardar los resultados en un archivo Excel
tabla_results_df.to_excel('tabla_results_df_otros.xlsx', index=False)
# Out:
# Estrategia de balanceo: RandomUnderSampler
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (RandomUnderSampler)
# - Accuracy: 0.6423
# - F1 score: 0.6491
# - Precision: 0.6617
# - Recall: 0.6423
# Confusion Matrix:
#  [[ 3  2  1  0  0  4]
#  [ 5  9  2  0  0  1]
#  [ 2  2 22  0  1  4]
#  [ 1  0  0 14  2  1]
#  [ 0  0  1  0 21  2]
#  [ 2  3  8  0  0 10]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (RandomUnderSampler)
# - Accuracy: 0.6260
# - F1 score: 0.6362
# - Precision: 0.6542
# - Recall: 0.6260
# Confusion Matrix:
#  [[ 5  0  3  0  0  2]
#  [ 5  8  1  0  0  3]
#  [ 2  4 20  1  1  3]
#  [ 2  0  0 14  2  0]
#  [ 2  0  2  2 18  0]
#  [ 2  4  5  0  0 12]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (RandomUnderSampler)
# - Accuracy: 0.7236
# - F1 score: 0.7223
# - Precision: 0.7264
# - Recall: 0.7236
# Confusion Matrix:
#  [[ 3  0  2  0  0  5]
#  [ 3 10  1  0  2  1]
#  [ 2  2 25  0  2  0]
#  [ 0  0  1 16  1  0]
#  [ 1  0  2  0 21  0]
#  [ 1  3  5  0  0 14]]
#
# Modelo: KNN
# Model performance for Test - KNN (RandomUnderSampler)
# - Accuracy: 0.6098
# - F1 score: 0.6037
# - Precision: 0.6542
# - Recall: 0.6098
# Confusion Matrix:
#  [[ 4  2  2  0  0  2]
#  [ 4  9  3  0  1  0]
#  [ 3  0 27  0  1  0]
#  [ 1  0  1 12  3  1]
#  [ 1  1  3  2 17  0]
#  [ 5  1 10  1  0  6]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (RandomUnderSampler)
# - Accuracy: 0.6341
# - F1 score: 0.6601
# - Precision: 0.6996
# - Recall: 0.6341
# Confusion Matrix:
#  [[ 3  3  0  0  0  4]
#  [ 4 11  1  0  0  1]
#  [ 8  0 20  1  0  2]
#  [ 2  0  2 14  0  0]
#  [ 1  0  1  0 21  1]
#  [ 5  4  5  0  0  9]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (RandomUnderSampler)
# - Accuracy: 0.6748
# - F1 score: 0.6748
# - Precision: 0.6904
# - Recall: 0.6748
# Confusion Matrix:
#  [[ 5  0  2  0  0  3]
#  [ 3  7  1  0  3  3]
#  [ 2  2 22  0  4  1]
#  [ 0  0  0 15  3  0]
#  [ 1  0  2  0 21  0]
#  [ 3  3  3  0  1 13]]
#
# Estrategia de balanceo: NearMiss
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (NearMiss)
# - Accuracy: 0.6179
# - F1 score: 0.6141
# - Precision: 0.6132
# - Recall: 0.6179
# Confusion Matrix:
#  [[ 1  1  3  1  0  4]
#  [ 3 10  1  0  0  3]
#  [ 0  1 19  1  2  8]
#  [ 0  1  0 15  2  0]
#  [ 1  0  2  2 19  0]
#  [ 2  2  7  0  0 12]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (NearMiss)
# - Accuracy: 0.5691
# - F1 score: 0.5738
# - Precision: 0.5892
# - Recall: 0.5691
# Confusion Matrix:
#  [[ 5  2  1  0  0  2]
#  [ 2  6  4  0  0  5]
#  [ 3  4 19  1  1  3]
#  [ 1  1  0 14  1  1]
#  [ 1  0  1  2 20  0]
#  [ 8  2  7  0  0  6]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (NearMiss)
# - Accuracy: 0.6829
# - F1 score: 0.6750
# - Precision: 0.6830
# - Recall: 0.6829
# Confusion Matrix:
#  [[ 4  1  1  0  0  4]
#  [ 2 10  2  0  1  2]
#  [ 1  4 24  0  2  0]
#  [ 0  0  0 17  1  0]
#  [ 1  0  1  0 22  0]
#  [ 4  6  6  0  0  7]]
#
# Modelo: KNN
# Model performance for Test - KNN (NearMiss)
# - Accuracy: 0.5447
# - F1 score: 0.5328
# - Precision: 0.5556
# - Recall: 0.5447
# Confusion Matrix:
#  [[ 3  0  4  0  0  3]
#  [ 3  7  4  0  0  3]
#  [ 2  0 23  2  1  3]
#  [ 0  0  1 13  4  0]
#  [ 1  1  2  3 17  0]
#  [ 5  1 11  1  1  4]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (NearMiss)
# - Accuracy: 0.6260
# - F1 score: 0.6260
# - Precision: 0.6427
# - Recall: 0.6260
# Confusion Matrix:
#  [[ 6  1  2  0  0  1]
#  [ 2  8  3  0  0  4]
#  [ 1  3 22  1  1  3]
#  [ 0  0  2 15  0  1]
#  [ 2  0  1  0 21  0]
#  [ 9  5  4  0  0  5]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (NearMiss)
# - Accuracy: 0.7317
# - F1 score: 0.7253
# - Precision: 0.7279
# - Recall: 0.7317
# Confusion Matrix:
#  [[ 2  1  1  0  1  5]
#  [ 2 10  2  0  1  2]
#  [ 1  2 25  0  2  1]
#  [ 0  0  1 15  2  0]
#  [ 1  0  0  0 23  0]
#  [ 2  1  4  0  1 15]]
#
# Estrategia de balanceo: CondensedNearestNeighbour
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CondensedNearestNeighbour)
# - Accuracy: 0.5772
# - F1 score: 0.5775
# - Precision: 0.5851
# - Recall: 0.5772
# Confusion Matrix:
#  [[ 1  4  1  0  0  4]
#  [ 1  9  5  0  0  2]
#  [ 0  0 21  0  1  9]
#  [ 1  1  1 13  2  0]
#  [ 0  0  0  2 18  4]
#  [ 2  6  5  1  0  9]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CondensedNearestNeighbour)
# - Accuracy: 0.5447
# - F1 score: 0.5422
# - Precision: 0.5840
# - Recall: 0.5447
# Confusion Matrix:
#  [[ 3  0  1  0  1  5]
#  [ 1  9  2  0  0  5]
#  [ 5  3  8  2  2 11]
#  [ 0  1  1 14  1  1]
#  [ 1  2  0  1 18  2]
#  [ 3  3  2  0  0 15]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (CondensedNearestNeighbour)
# - Accuracy: 0.6748
# - F1 score: 0.6763
# - Precision: 0.6906
# - Recall: 0.6748
# Confusion Matrix:
#  [[ 4  3  1  0  0  2]
#  [ 1 13  2  0  0  1]
#  [ 1  3 20  0  2  5]
#  [ 1  0  2 15  0  0]
#  [ 0  1  2  0 21  0]
#  [ 3  6  3  0  1 10]]
#
# Modelo: KNN
# Model performance for Test - KNN (CondensedNearestNeighbour)
# - Accuracy: 0.4472
# - F1 score: 0.4404
# - Precision: 0.5760
# - Recall: 0.4472
# Confusion Matrix:
#  [[ 1  5  1  0  0  3]
#  [ 2 11  3  0  0  1]
#  [ 4  1 22  0  0  4]
#  [ 4  1 10  3  0  0]
#  [ 3  1  6  0 14  0]
#  [ 3  6 10  0  0  4]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CondensedNearestNeighbour)
# - Accuracy: 0.6341
# - F1 score: 0.6377
# - Precision: 0.6439
# - Recall: 0.6341
# Confusion Matrix:
#  [[ 3  1  2  1  0  3]
#  [ 4  8  3  0  0  2]
#  [ 0  3 22  0  2  4]
#  [ 1  0  0 14  1  2]
#  [ 0  0  1  0 21  2]
#  [ 3  5  5  0  0 10]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CondensedNearestNeighbour)
# - Accuracy: 0.6260
# - F1 score: 0.6200
# - Precision: 0.6203
# - Recall: 0.6260
# Confusion Matrix:
#  [[ 2  0  2  0  0  6]
#  [ 1 10  2  0  3  1]
#  [ 3  4 17  1  4  2]
#  [ 1  0  0 15  2  0]
#  [ 1  0  0  3 20  0]
#  [ 1  3  5  0  1 13]]
#
# Estrategia de balanceo: CTGAN
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CTGAN)
# - Accuracy: 0.1951
# - F1 score: 0.1650
# - Precision: 0.1878
# - Recall: 0.1951
# Confusion Matrix:
#  [[ 0  1  1  4  1  3]
#  [ 0  0  1  4  6  6]
#  [ 0  1  5 11  0 14]
#  [ 0  1  3  8  0  6]
#  [ 0  0  0 21  2  1]
#  [ 0  2  4  5  3  9]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CTGAN)
# - Accuracy: 0.1626
# - F1 score: 0.1192
# - Precision: 0.1247
# - Recall: 0.1626
# Confusion Matrix:
#  [[ 1  3  0  0  6  0]
#  [ 0  9  0  1  7  0]
#  [ 0 11  0  0  9 11]
#  [ 0  6  0  0  5  7]
#  [ 0 14  0  1  4  5]
#  [ 1  6  0  2  8  6]]
#
# Modelo: Random Forest
# c:\Users\FloCr\.anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\FloCr\.anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\FloCr\.anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# c:\Users\FloCr\.anaconda\Lib\site-packages\sklearn\metrics\_classification.py:1517: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", len(result))
# Model performance for Test - Random Forest (CTGAN)
# - Accuracy: 0.2276
# - F1 score: 0.1938
# - Precision: 0.3209
# - Recall: 0.2276
# Confusion Matrix:
#  [[ 0  2  0  8  0  0]
#  [ 0  2  0  7  2  6]
#  [ 0  3  4  5  7 12]
#  [ 0  0  0 12  1  5]
#  [ 0  5  0  9  2  8]
#  [ 0  2  1  9  3  8]]
#
# Modelo: KNN
# Model performance for Test - KNN (CTGAN)
# - Accuracy: 0.2195
# - F1 score: 0.1815
# - Precision: 0.2124
# - Recall: 0.2195
# Confusion Matrix:
#  [[ 2  0  1  5  1  1]
#  [ 4  5  2  3  0  3]
#  [ 1  2  3 19  0  6]
#  [ 0  0  2 13  0  3]
#  [ 1  1  4 18  0  0]
#  [ 4  2  1 11  1  4]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CTGAN)
# - Accuracy: 0.1301
# - F1 score: 0.0807
# - Precision: 0.0648
# - Recall: 0.1301
# Confusion Matrix:
#  [[ 0  3  0  6  1  0]
#  [ 0  5  1  9  0  2]
#  [ 0  8  0 13  0 10]
#  [ 0  6  0  8  0  4]
#  [ 0 18  0  5  0  1]
#  [ 0  7  1 12  0  3]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CTGAN)
# - Accuracy: 0.2195
# - F1 score: 0.1911
# - Precision: 0.2809
# - Recall: 0.2195
# Confusion Matrix:
#  [[ 0  1  1  5  1  2]
#  [ 0  7  0  8  0  2]
#  [ 1  8  4  4  3 11]
#  [ 0  4  1 10  0  3]
#  [ 0  8  1 12  2  1]
#  [ 1  8  1  9  0  4]]
#
# Estrategia de balanceo: CTGAN + RandomUnderSampler
#
# Modelo: Logistic Regression
# Model performance for Test - Logistic Regression (CTGAN + RandomUnderSampler)
# - Accuracy: 0.6179
# - F1 score: 0.6018
# - Precision: 0.6031
# - Recall: 0.6179
# Confusion Matrix:
#  [[ 2  1  2  1  0  4]
#  [ 2  5  4  3  0  3]
#  [ 0  1 27  1  0  2]
#  [ 0  1  2 12  3  0]
#  [ 1  2  1  1 19  0]
#  [ 3  0  5  3  1 11]]
#
# Modelo: Decision Tree
# Model performance for Test - Decision Tree (CTGAN + RandomUnderSampler)
# - Accuracy: 0.6179
# - F1 score: 0.6271
# - Precision: 0.6510
# - Recall: 0.6179
# Confusion Matrix:
#  [[ 4  1  2  0  0  3]
#  [ 3  5  4  0  0  5]
#  [ 6  1 19  0  1  4]
#  [ 0  0  0 15  2  1]
#  [ 1  1  0  0 22  0]
#  [ 6  2  3  1  0 11]]
#
# Modelo: Random Forest
# Model performance for Test - Random Forest (CTGAN + RandomUnderSampler)
# - Accuracy: 0.6992
# - F1 score: 0.6963
# - Precision: 0.7093
# - Recall: 0.6992
# Confusion Matrix:
#  [[ 2  0  3  0  0  5]
#  [ 1  9  2  0  0  5]
#  [ 2  1 25  0  2  1]
#  [ 0  0  2 16  0  0]
#  [ 1  0  2  0 21  0]
#  [ 2  1  6  0  1 13]]
#
# Modelo: KNN
# Model performance for Test - KNN (CTGAN + RandomUnderSampler)
# - Accuracy: 0.5854
# - F1 score: 0.5733
# - Precision: 0.5977
# - Recall: 0.5854
# Confusion Matrix:
#  [[ 2  1  3  0  0  4]
#  [ 3  7  5  0  0  2]
#  [ 1  0 27  0  1  2]
#  [ 1  1  1 13  2  0]
#  [ 1  1  3  1 18  0]
#  [ 5  1 10  1  1  5]]
#
# Modelo: AdaBoost
# Model performance for Test - AdaBoost (CTGAN + RandomUnderSampler)
# - Accuracy: 0.6260
# - F1 score: 0.6317
# - Precision: 0.6631
# - Recall: 0.6260
# Confusion Matrix:
#  [[ 2  2  2  0  0  4]
#  [ 9  3  2  0  1  2]
#  [ 3  0 24  0  1  3]
#  [ 0  0  1 14  0  3]
#  [ 1  1  3  0 19  0]
#  [ 3  1  4  0  0 15]]
#
# Modelo: Gradient Boosting
# Model performance for Test - Gradient Boosting (CTGAN + RandomUnderSampler)
# - Accuracy: 0.7073
# - F1 score: 0.6953
# - Precision: 0.6998
# - Recall: 0.7073
# Confusion Matrix:
#  [[ 2  1  2  0  0  5]
#  [ 2  6  2  0  1  6]
#  [ 1  1 27  0  2  0]
#  [ 0  0  0 15  3  0]
#  [ 1  0  1  0 22  0]
#  [ 2  2  4  0  0 15]]
